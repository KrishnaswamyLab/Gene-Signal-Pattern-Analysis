# %% [markdown]
# # 1.0_calculate_pt_features calculates patient features for GSPA and comparisons

# %%
import sys
sys.path.append('/home/aarthivenkat/Gene-Signal-Pattern-Analysis')
from gspa import calculate_wavelet_dictionary
from utils import learn_representation
from ae import run_ae
import pandas as pd
import numpy as np
import scanpy, phate
from sklearn import preprocessing

# %%
data = scanpy.read_h5ad('/data/lab/datasets/cpi_melanoma/processed_data.h5ad')
# subset to those samples with known response
data = data[data.obs['response'].isin(['NR', 'R'])]

# %%
# generate cell-cell graph
phate_op = phate.PHATE(random_state=42, verbose=False)
data_phate = phate_op.fit_transform(data.to_df())
G = phate_op.graph.to_pygsp()
del(phate_op)

# %% [markdown]
# ## GSPA patient indicator

# %%
dictionary_full, wavelet_sizes = calculate_wavelet_dictionary(G, use_reduced=False)
# Out:
# Maximum scale: 9
# Calculating Wavelets J = 9
# 100%|██████████| 7/7 [02:47<00:00, 23.95s/it]

# %%
patient_indicator = preprocessing.OneHotEncoder().fit_transform(np.array(data.obs['patient']).reshape(-1,1)).T.todense()
patient_indicator = patient_indicator / np.linalg.norm(patient_indicator, axis=1).reshape(-1,1)

# %%
patient_signal_reduced = learn_representation(patient_indicator, dictionary_full)
patient_signal_ae = run_ae(patient_signal_reduced)
# Out:
# /home/aarthivenkat/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# Epoch 1/100
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0842 - val_loss: 0.0716
# Epoch 2/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0722 - val_loss: 0.0712
# Epoch 3/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0685 - val_loss: 0.0706
# Epoch 4/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0635 - val_loss: 0.0693
# Epoch 5/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0575 - val_loss: 0.0668
# Epoch 6/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0503 - val_loss: 0.0628
# Epoch 7/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0438 - val_loss: 0.0590
# Epoch 8/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0386 - val_loss: 0.0551
# Epoch 9/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0353 - val_loss: 0.0514
# Epoch 10/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0328 - val_loss: 0.0492
# Epoch 11/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0301 - val_loss: 0.0491
# Epoch 12/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0281 - val_loss: 0.0494
# Epoch 13/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0266 - val_loss: 0.0489
# Epoch 14/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0251 - val_loss: 0.0481
# Epoch 15/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0237 - val_loss: 0.0472
# Epoch 16/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0222 - val_loss: 0.0464
# Epoch 17/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0209 - val_loss: 0.0454
# Epoch 18/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0195 - val_loss: 0.0453
# Epoch 19/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0187 - val_loss: 0.0456
# Epoch 20/100
# 2/2 [==============================] - 0s 19ms/step - loss: 0.0177 - val_loss: 0.0455
# Epoch 21/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0167 - val_loss: 0.0454
# Epoch 22/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0160 - val_loss: 0.0452
# Epoch 23/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0151 - val_loss: 0.0451
# Epoch 24/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0144 - val_loss: 0.0452
# Epoch 25/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0137 - val_loss: 0.0452
# Epoch 26/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0131 - val_loss: 0.0446
# Epoch 27/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0125 - val_loss: 0.0441
# Epoch 28/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0121 - val_loss: 0.0444
# Epoch 29/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0115 - val_loss: 0.0451
# Epoch 30/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0111 - val_loss: 0.0452
# Epoch 31/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0106 - val_loss: 0.0446
# Epoch 32/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0102 - val_loss: 0.0444
# Epoch 33/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0100 - val_loss: 0.0451
# Epoch 34/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0096 - val_loss: 0.0455
# Epoch 35/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0093 - val_loss: 0.0448
# Epoch 36/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0090 - val_loss: 0.0441
# Epoch 37/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0087 - val_loss: 0.0446
# Epoch 38/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0085 - val_loss: 0.0450
# Epoch 39/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0083 - val_loss: 0.0447
# Epoch 40/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0080 - val_loss: 0.0446
# Epoch 41/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0078 - val_loss: 0.0449
# Epoch 42/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0077 - val_loss: 0.0451
# Epoch 43/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0075 - val_loss: 0.0450
# Epoch 44/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0073 - val_loss: 0.0450
# Epoch 45/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0071 - val_loss: 0.0447
# Epoch 46/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0070 - val_loss: 0.0448
# Epoch 47/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0068 - val_loss: 0.0450
# Epoch 48/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0066 - val_loss: 0.0446
# Epoch 49/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0065 - val_loss: 0.0442
# Epoch 50/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0064 - val_loss: 0.0442
# Epoch 51/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0063 - val_loss: 0.0442
# Epoch 52/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0062 - val_loss: 0.0443
# Epoch 53/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0061 - val_loss: 0.0444
# Epoch 54/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0060 - val_loss: 0.0443
# Epoch 55/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0059 - val_loss: 0.0442
# Epoch 56/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0058 - val_loss: 0.0441
# Epoch 57/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0057 - val_loss: 0.0440
# Epoch 58/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0056 - val_loss: 0.0438
# Epoch 59/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0055 - val_loss: 0.0438
# Epoch 60/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0054 - val_loss: 0.0439
# Epoch 61/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0053 - val_loss: 0.0439
# Epoch 62/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0053 - val_loss: 0.0438
# Epoch 63/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0052 - val_loss: 0.0439
# Epoch 64/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0050 - val_loss: 0.0437
# Epoch 65/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0050 - val_loss: 0.0435
# Epoch 66/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0049 - val_loss: 0.0436
# Epoch 67/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0048 - val_loss: 0.0435
# Epoch 68/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0048 - val_loss: 0.0433
# Epoch 69/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0047 - val_loss: 0.0433
# Epoch 70/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0046 - val_loss: 0.0433
# Epoch 71/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0046 - val_loss: 0.0431
# Epoch 72/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0045 - val_loss: 0.0427
# Epoch 73/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0045 - val_loss: 0.0428
# Epoch 74/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0044 - val_loss: 0.0430
# Epoch 75/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0043 - val_loss: 0.0428
# Epoch 76/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0043 - val_loss: 0.0426
# Epoch 77/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0043 - val_loss: 0.0426
# Epoch 78/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0042 - val_loss: 0.0426
# Epoch 79/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0042 - val_loss: 0.0425
# Epoch 80/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0041 - val_loss: 0.0422
# Epoch 81/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0041 - val_loss: 0.0419
# Epoch 82/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0040 - val_loss: 0.0422
# Epoch 83/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0040 - val_loss: 0.0422
# Epoch 84/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0039 - val_loss: 0.0417
# Epoch 85/100
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0039 - val_loss: 0.0419
# Epoch 86/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0038 - val_loss: 0.0421
# Epoch 87/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0038 - val_loss: 0.0417
# Epoch 88/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0038 - val_loss: 0.0416
# Epoch 89/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0037 - val_loss: 0.0415
# Epoch 90/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0037 - val_loss: 0.0415
# Epoch 91/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0037 - val_loss: 0.0414
# Epoch 92/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0036 - val_loss: 0.0414
# Epoch 93/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0036 - val_loss: 0.0411
# Epoch 94/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0036 - val_loss: 0.0410
# Epoch 95/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0036 - val_loss: 0.0413
# Epoch 96/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0036 - val_loss: 0.0418
# Epoch 97/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0035 - val_loss: 0.0421
# Epoch 98/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0035 - val_loss: 0.0421
# Epoch 99/100
# 2/2 [==============================] - 0s 22ms/step - loss: 0.0035 - val_loss: 0.0411
# Epoch 100/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0035 - val_loss: 0.0409

# %%
np.save('results/GSPA_patient.npy', patient_signal_ae)

# %% [markdown]
# ## GSPA+QR gene signals

# %%
dictionary, wavelet_sizes = calculate_wavelet_dictionary(G)

# %%
all_patients_reduced = []

# %%
for i,pt in enumerate(np.unique(data.obs['patient'])):
    patient = data[data.obs['patient'] == pt].to_df().T.values
    pat_gene_reduced = learn_representation(patient, dictionary[data.obs['patient'] == pt])
    all_patients_reduced.append(pat_gene_reduced[:, :5])
# Out:
# 0 Post_P1
# 1 Post_P10
# 2 Post_P11
# 3 Post_P12
# 4 Post_P13
# 5 Post_P14
# 6 Post_P15
# 7 Post_P16
# 8 Post_P17
# 9 Post_P18
# 10 Post_P19
# 11 Post_P1_2
# 12 Post_P2
# 13 Post_P20
# 14 Post_P21
# 15 Post_P22
# 16 Post_P23
# 17 Post_P23_2
# 18 Post_P28
# 19 Post_P28_2
# 20 Post_P3
# 21 Post_P30
# 22 Post_P3_2
# 23 Post_P4
# 24 Post_P5
# 25 Post_P5_2
# 26 Post_P6
# 27 Post_P7
# 28 Post_P8
# 29 Pre_P1
# 30 Pre_P12
# 31 Pre_P15
# 32 Pre_P2
# 33 Pre_P20
# 34 Pre_P24
# 35 Pre_P25
# 36 Pre_P26
# 37 Pre_P27
# 38 Pre_P28
# 39 Pre_P29
# 40 Pre_P3
# 41 Pre_P31
# 42 Pre_P33
# 43 Pre_P35
# 44 Pre_P4
# 45 Pre_P6
# 46 Pre_P7
# 47 Pre_P8

# %%
np.save('results/GSPA_gene.npy', np.array(all_patients_reduced))

# %% [markdown]
# ## Mean expression

# %%
mean_patients = []
for patient in np.unique(data.obs['patient']):
    pat = data[data.obs['patient'] == patient]
    mean_patients.append(pat.to_df().mean(axis=0))

# %%
np.save('results/mean.npy', np.array(mean_patients))

# %% [markdown]
# ## Cluster proportion, CD8

# %%
data_cd8 = data[data.obs['isCD8'], :]
patient_proportions = pd.DataFrame(index=np.unique(data_cd8.obs['patient']), columns=np.unique(data_cd8.obs['cluster_cd8']))
for patient in np.unique(data_cd8.obs['patient']):
    pat = data_cd8[data_cd8.obs['patient'] == patient]
    pat_prop = pat.obs['cluster_cd8'].value_counts() / pat.n_obs
    patient_proportions.loc[patient] = pat_prop

patient_proportions.fillna(0, inplace=True)

# %%
np.save('results/proportion_cd8.npy', np.array(patient_proportions))

# %% [markdown]
# ## Cluster proportion, all

# %%
patient_proportions = pd.DataFrame(index=np.unique(data.obs['patient']), columns=np.unique(data.obs['cluster_all']))
for patient in np.unique(data.obs['patient']):
    pat = data[data.obs['patient'] == patient]
    pat_prop = pat.obs['cluster_all'].value_counts() / pat.n_obs
    patient_proportions.loc[patient] = pat_prop

patient_proportions.fillna(0, inplace=True)

# %%
np.save('results/proportion_all.npy', np.array(patient_proportions))
